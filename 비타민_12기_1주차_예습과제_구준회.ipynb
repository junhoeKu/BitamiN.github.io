# %% [markdown]
# ## 시계열 세션 예습과제
#
# 아래 링크의 논문을 참고하여 예습과제를 해결해주세요.
#
# https://arxiv.org/abs/2204.11115

# %% [markdown]
# 1. 시계열 예측은 과거 관측값을 바탕으로 타겟 변수의 미래 시점에서의 [ 분포 ]를 예측하기 위해 사용된다.

# %% [markdown]
# 2. 전통적 시계열 모델은 ( 선형 )와 ( 비선형 )으로 나눌 수 있다.

# %% [markdown]
# 3. ARIMA 모델은 ( 비정상성 )을 띄는 시계열을 다룰 수 있는 모델이다.

# %% [markdown]
# 4. ARCH 모델은 ( 비선형 ) 모델이다.

# %% [markdown]
# 5. 변동성이 심한 시계열의 [ 정상성 ]을 만족하기 어려운 것이 시계열 모델의 단점 중 하나이다.

# %% [markdown]
# 6. 딥러닝 모델은 과거 데이터와 타겟 변수의 미래 값 간의 [ 함수적 관계 ]를 학습한다.

# %% [markdown]
# 7. 아래 LSTM의 도식을 보고 $C_t$를 이루고 있는 변수 3가지를 모두 쓰세요.
#   - Ct-1
#   - ft
#   - it * Ct

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. 아래 GRU의 도식을 보고 $(1-z_t)  S_{t-1}$의 역할을 설명하세요.
#   - 업데이트하는 데 있어서 이전 상태에서 유지해야 할 정보의 양을 결정하는 것

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. 트랜스포머 모델은 과거의 중요한 정보에 선별적으로 가중치를 부여하는 [ Self Attention ]을 주로 사용하기 때문에 시계열에 대해 가장 좋은 성능을 보이는 것으로 알려져 있다.

# %% [markdown]
# 10. 아래 트랜스포머의 도식을 보고 Encoder가 어떤 데이터를 받고 어떤 데이터를 출력하는지 설명하세요.
#   - Input Layer를 데이터로 받고 Feature Vector를 출력한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11. 사용하는 과거 데이터가 많을수록 [ Transformer ] 모델이, 적을수록 [ LSTM ] 모델과 [ GRU ] 모델이 예측에 유리하다.
