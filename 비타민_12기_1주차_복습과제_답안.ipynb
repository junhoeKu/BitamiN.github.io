# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# ## Matplotlib(맷플롯립)

# %% [markdown]
# #### 아래 그림과 같은 그래프를 만들어주세요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1-0. 아래 코드를 실행해주세요.

# %%
x = np.arange(1, 6)
y = [3,3,3,3,3]

# %%
# 1-1. figure을 설정해주세요
plt.figure(figsize=(10,5), facecolor='orange')

# 1-2. x, y범위를 설정해주세요.
plt.xticks(np.arange(1,6))
plt.yticks(np.arange(1,6))

plt.xlim(0.5, 5.5)
plt.ylim(0.5, 5.5)

# 1-3. X, y그래프를 꾸며주세요.
plt.plot(x, x, color = 'red', marker = 'o')
plt.plot(x, y, '--')

# 1-4. 제목과 축제목, 범례를 설정해주세요.
plt.xlabel('X_value')
plt.ylabel('y_value')

plt.title('Happy Vacation')
plt.legend(('X', 'y'))

# 1-5. 그래프를 출력해주세요.
plt.show()
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# ...

# %% [markdown]
# # Seaborn

# %%
train = pd.read_csv('titanic_train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ---

# %% [markdown]
# ## 2-1. 생존(Survived) 비율
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
train["Survived"].value_counts()

plt.figure(figsize=(8, 5))
labels = ['사망', '생존']
train['Survived'].value_counts().plot.pie(explode=[0, 0.08],
                                          shadow=True,
                                          autopct='%1.1f%%',
                                          labels=labels)
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# ## 2-2. 성별 (Sex)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].set_title("성별 탑승자 수 \n", size=15)
sns.countplot(x="Sex", data=train, ax=axes[0])

axes[1].set_title("성별 생존자 수 \n", size=15)
sns.countplot(x="Sex", hue="Survived", data=train, ax=axes[1])
axes[1].legend(labels = ['사망', '생존'])

# %% [markdown]
# ## 2-3. 티켓 클래스 (Pclass)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].set_title("클래스별 탑승수 \n", size=15)
sns.countplot(data=train, x='Pclass', ax=axes[0])

axes[1].set_title("클래스별 생존/사망 수 \n", size=15)
sns.countplot(x="Pclass", hue="Survived", data=train, ax=axes[1])
axes[1].legend(labels = ['사망', '생존'])

# %% [markdown]
# ## 2-4. 나이 (Age)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(8, 5))
sns.distplot(train['Age'], bins=25)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## 2-5. 가족의 수 (SibSp, Parch)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

axes[0][0].set_title("SibSp별 탑승자 수", size=15)
sns.countplot(x="SibSp", data=train, ax=axes[0][0], palette="Set2")
axes[0][1].set_title("Parch별 탑승자 수", size=15)
sns.countplot(x="Parch", data=train, ax=axes[0][1], palette="Set2")

axes[1][0].set_title("SibSp별 생존 여부", size=15)
sns.countplot(x="SibSp", hue="Survived", data=train, ax=axes[1][0], palette="Set2")
axes[1][0].legend(loc='upper right')
axes[1][1].set_title("Parch별 생존 여부", size=15)
sns.countplot(x="Parch", hue="Survived", data=train, ax=axes[1][1], palette="Set2")
axes[1][1].legend(loc='upper right')

# %% [markdown]
# ## 2-6. 탑승 항구 (Embarked)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].set_title("성별 탑승자 수 \n", size=15)
sns.countplot(x="Embarked", data=train, ax=axes[0])

axes[1].set_title("성별 생존 여부 \n", size=15)
sns.countplot(x="Embarked", hue="Survived", data=train, ax=axes[1])
axes[1].legend(labels = ['사망', '생존'])

# %% [markdown]
# ## 2-7. 탑승 금액 (Fare)
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(train[train['Survived']==1]['Fare'], ax=ax)
sns.kdeplot(train[train['Survived']==0]['Fare'], ax=ax)

ax.set(xlim=(0, train['Fare'].max()))
ax.legend(['생존', '사망'])

plt.show()

# %% [markdown]
# ## 2-8. Heatmap
# 다음과 같이 시각화하시오.
#
# ![image.png](attachment:image.png)

# %%
corr = train.corr()
sns.heatmap(corr, annot=True, fmt='.1f', cbar=True)
plt.show()

# %% [markdown]
# # 문제3.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

titanic = pd.read_csv('titanic.csv')
titanic

# %% [markdown]
# 3-1 ) titanic의 열 중 'Name', 'Cabin', 'Ticket' 열을 삭제해 titanic_df의 변수에 저장한 후 null값을 처리해주세요.

# %%
titanic_df = titanic.drop(columns=['Name','Cabin','Ticket'])
titanic_df

# %%
titanic_df.info()

# %%
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].mean())

# %%
titanic_df.info()

# %% [markdown]
# 3-2) 다음 빈칸에 적절한 변수명을 적어주세요. <br/>
# 범주형 변수 중 [      ] 는 one-hot 인코딩을 통해, [         ] 은 label 인코딩을 통해 변환한다.

# %% [markdown]
# 답 : Sex , Embarked

# %% [markdown]
# 3-3) 1-2에서 적은 답을 이용해 라벨링을 진행해주세요.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

titanic_df['Embarked'] = le.fit_transform(titanic_df['Embarked'])

# %%
titanic_df = pd.get_dummies(titanic_df, columns = ['Sex'])
titanic_df

# %% [markdown]
# 3-4) 다음 빈칸을 채워 평가지표와 ROC 그래프를 출력하는 함수를 완성시켜주세요.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve

# %%
def get_clf_eval(y_test, y_pred):
    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred)
    AUC = roc_auc_score(y_test, y_pred)

    print('오차행렬:\n', confusion)
    print('\n정확도: {:.4f}'.format(accuracy))
    print('정밀도: {:.4f}'.format(precision))
    print('재현율: {:.4f}'.format(recall))
    print('F1: {:.4f}'.format(F1))
    print('AUC: {:.4f}'.format(AUC))

def precision_recall_curve_plot(y_test, pred_proba):
    # threshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba)

    # x축을 threshold, y축을 정밀도, 재현율로 그래프 그리기
    plt.figure(figsize=(8, 6))
    thresholds_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[:thresholds_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[:thresholds_boundary], linestyle=':', label='recall')

    # threshold의 값 X축의 scale을 0.1 단위로 변경
    stard, end = plt.xlim()
    plt.xticks(np.round(np.arange(stard, end, 0.1), 2))

    plt.xlim()
    plt.xlabel('thresholds')
    plt.ylabel('precision & recall value')
    plt.legend()
    plt.grid()

# %%
# 그냥 실행하는 코드
from sklearn.model_selection import train_test_split

X  = titanic_df.drop(columns=['Survived'])
y= titanic_df['Survived']

# 데이터를 훈련과 테스트 데이터 셋으로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 156)

# %% [markdown]
# 3-5) 로지스틱 회귀 변수 lr_clf를 선언 한 뒤 예측 및 평가를 진행해주세요. <br/>이 때 평가지표는 위에서 생성했던 함수를 사용합니다.

# %%
from sklearn.linear_model import LogisticRegression

# 로지스틱 회귀로 학습, 예측 및 평가 수행
lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)

#평가 지표 출력
get_clf_eval(y_test, pred)

# 임계값별 정밀도 - 재현율 출력
pred_proba = lr_clf.predict_proba(X_test)[:, 1]
precision_recall_curve_plot(y_test, pred_proba)

# %% [markdown]
# 3-6) 아래는 Binarizer()를 이용해 예측 값을 이항변수로 변환하여 임계값에 따른 평가지표를 출력하는 함수입니다. 빈칸을 채워 코드를 실행시켜주세요.

# %%
from sklearn.preprocessing import Binarizer

# 평가지표를 조사하기 위한 새로운 함수 생성
def get_eval_by_threshold(y_test, pred_proba_c1, thresholds):
    #thresholds list 객체 내의 값을 iteration 하면서 평가 수행
    for custom_threshold in thresholds:
        binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_c1)
        custom_predict = binarizer.transform(pred_proba_c1)
        print('\n임계값: ', custom_threshold)
        get_clf_eval(y_test, custom_predict)

thresholds = [0.3, 0.33, 0.36, 0.39, 0.42, 0.45, 0.48, 0.50]
pred_proba = lr_clf.predict_proba(X_test)
get_eval_by_threshold(y_test, pred_proba[:, 1].reshape(-1, 1), thresholds)

# %% [markdown]
# 3-7) 아래 빈칸을 채운 후 빈칸에 들어갈 행위를 코드로 구현해주세요. <br/>
#         SVM 활용에서 커널 함수를 활용하기 위해서는 반드시 [       ] 과정이 필요하다.

# %% [markdown]
# 답 : 정규화

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=156)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# 3-8) SVM 모델 변수 svm_model을 선언 한 뒤 예측 및 평가를 진행해주세요. <br/>이 때 평가지표는 위에서 생성했던 함수를 사용합니다.

# %%
svm_model = SVC(random_state= 156,probability=True)
svm_model.fit(X_train,y_train)
y_pred = svm_model.predict(X_test)
get_clf_eval(y_test, y_pred)

# %% [markdown]
# 3-9) 위에서 생성한 roc_curve 함수를 통해 ROC curve 그래프를 그려주세요.

# %%
pred_proba = svm_model.predict_proba(X_test)

# ROC curve
fpr, tpr, thresholds = roc_curve(y_test, pred_proba[:,1])

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc_score(y_test, pred_proba[:,1]))
plt.plot([0, 1], [0, 1], 'k--')  # 대각 점선 추가 (랜덤 모델의 ROC curve)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# 혼동 행렬 계산 및 시각화
cm = confusion_matrix(y_test, pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 문제3 (50점)

# %% [markdown]
# ### 1. 데이터프레임 titanic의 상관관계를 나타내는 히트맵을 그리는 코드를 작성하세요. (5점)
# (필요한 경우 custom_colors의 색상 코드 사용)

# %%
custom_colors = ["#85CEDA","#D2A7D8", "#A67BC5", "#BB1C8B", "#05A4C0"]

titanic.corr
f,ax = plt.subplots(figsize=(15,10))
sns.heatmap(titanic.corr(), annot =True, linewidth =".5", fmt =".2f", cmap=custom_colors)
plt.show()

# %%
# 문제X

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 156)

# %% [markdown]
# ### 2. 랜덤 포레스트를 사용하면 모델의 일반화 성능을 향상시킬 수 있기 때문에 일반적으로 의사결정트리보다 분산을 줄이는 효과가 있다.  (5점)
#
# (참 / 거짓)

# %%
# 답: 참

# %% [markdown]
# ### 3. (a)는 다중공선성으로 인한 분산의 팽창을 의미한다. 즉, 값이 클수록 다중공선성이 높음을 의미한다. (a)에 들어갈 단어는? (5점)
#
# (1) VIF
# (2) 회귀계수
# (3) MSE
# (4) p-value

# %%
# 답: (1)

# %% [markdown]
# ### 4. 다음 조건을 만족하는 랜덤 포레스트 모델을 만든 후, 학습 및 예측을 진행하세요. (8점)
# - 결정 트리 분할 기준: 지 불순도를 사용하여 노드를 분할하도록 설정
# - 랜덤포레스트를 구성하는 결정트리 개수: 1700개
# - 결정 트리의 최대 깊이: 7
# - 노드를 분할하기 위한 최소한의 샘플 데이터 수: 5개
# - 리프노드가 되기 위해 필요한 최소한의 샘플 데이터 수: 6개

# %%
# 모델 생성
rf = RandomForestClassifier(criterion='gini',
                                           n_estimators=1750,
                                           max_depth=7,
                                           min_samples_split=6,
                                           min_samples_leaf=6,
                                           max_features='auto',
                                           oob_score=True,
                                           random_state=42,
                                           n_jobs=-1,
                                           verbose=1)
# 학습 수행
rf.fit(X_train, y_train)

# 예측 수행
pred_rf = rf.predict(X_test)

# %% [markdown]
# ### 5. 의사결정트리 모델을 만든 후, 학습 및 예측을 진행하세요.(random_state) =  42  (5점)

# %%
# 의사결정트리 모델 생성
dt = DecisionTreeClassifier(random_state=42)

# 학습 수행
dt.fit(X_train, y_train)

# 예측 수행
pred_dt = dt.predict(X_test)

# %% [markdown]
# ### 6. 생성한 랜덤포레스트, 의사결정 모델의 classification report를 각각 출력하세요. (4점)

# %%
print(classification_report(y_test, pred_dt))
print("===========================================================")
print(classification_report(y_test, pred_rf))

# %% [markdown]
# ### 7. 생성한 의사결정트리 모델을 시각화하세요. (8점)

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(10,7))
plot_tree(dt)
plt.show()

# %% [markdown]
# ### 8. 의사결정트리와 랜덤포레스트 모델의 피처 중요도를 나타내는 그래프를 시각화하세요. (10점)

# %%
# 의사결정트리의 피처 중요도 시각화
sns.barplot(x=dt.feature_importances_, y=X.columns)

# %%
# 의사결정트리의 피처 중요도 시각화
sns.barplot(x=rf.feature_importances_, y=X.columns)
